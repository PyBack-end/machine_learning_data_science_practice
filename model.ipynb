# %%
# !conda install pandas numpy scikit-learn imbalanced-learn
import json
import warnings
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report , confusion_matrix , precision_recall_fscore_support
from imblearn.over_sampling import SMOTE
# Out:
# mambajs 0.19.13
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas, scikit-learn, imbalanced-learn
# Channels: emscripten-forge, conda-forge
#
# Solving environment...
# Solving took 3.78839999999851 seconds
# All requested packages already installed.

# %%
recommandation_database = [
    {
        "stream": "STEM",
        "field_name": "Medicine & Health Care",
        "subject_name": "Biology",
        "requirement_type": "Required",
        "descriptions": "Essential for understanding human anatomy and physiology"
    },
    {
        "stream": "STEM",
        "field_name": "Medicine & Health Care",
        "subject_name": "Chemistry",
        "requirement_type": "Required",
        "descriptions": "Core science for pharmacology and biochemistry"
    },
    {
        "stream": "STEM",
        "field_name": "Medicine & Health Care",
        "subject_name": "Physical Sciences",
        "requirement_type": "Required",
        "descriptions": "Physics principles in medical technology and diagnostics"
    },
    {
        "stream": "STEM",
        "field_name": "Medicine & Health Care",
        "subject_name": "Mathematics",
        "requirement_type": "Required",
        "descriptions": "Analytical skills for healthcare data and calculations"
    },
    {
        "stream": "STEM",
        "field_name": "Medicine & Health Care",
        "subject_name": "Life Sciences",
        "requirement_type": "Recommended",
        "descriptions": "Understanding of living organisms, disease mechanisms, and biological processes"
    },
    {
        "stream": "STEM",
        "field_name": "Engineering",
        "subject_name": "Mathematics",
        "requirement_type": "Required",
        "descriptions": "Foundation for engineering calculations and analysis"
    },
    {
        "stream": "STEM",
        "field_name": "Engineering",
        "subject_name": "Physical Sciences",
        "requirement_type": "Required",
        "descriptions": "Core engineering principles and mechanics"
    },
    {
        "stream": "STEM",
        "field_name": "Engineering",
        "subject_name": "Chemistry",
        "requirement_type": "Required",
        "descriptions": "Chemical processes and material science"
    },
    {
        "stream": "STEM",
        "field_name": "Engineering",
        "subject_name": "Technical Drawing",
        "requirement_type": "Recommended",
        "descriptions": "Visual language for communicating complex design information"
    },
    {
        "stream": "STEM",
        "field_name": "Technology",
        "subject_name": "Mathematics",
        "requirement_type": "Required",
        "descriptions": "Engineering design and visualization skills"
    },
    {
        "stream": "STEM",
        "field_name": "Technology",
        "subject_name": "Physical Sciences",
        "requirement_type": "Required",
        "descriptions": "Modern engineering software and tools"
    },
    {
        "stream": "STEM",
        "field_name": "Technology",
        "subject_name": "Computer Applications Technology",
        "requirement_type": "Required",
        "descriptions": "Algorithmic thinking and computational logic"
    },
    {
        "stream": "STEM",
        "field_name": "Technology",
        "subject_name": "Information Technology",
        "requirement_type": "Required",
        "descriptions": "IT fundamentals and software skills"
    },
    {
        "stream": "STEM",
        "field_name": "Science and Research",
        "subject_name": "Physical Sciences",
        "requirement_type": "Required",
        "descriptions": "Physics and chemistry fundamentals"
    },
    {
        "stream": "STEM",
        "field_name": "Science and Research",
        "subject_name": "Life Sciences",
        "requirement_type": "Required",
        "descriptions": "Biology and environmental science"
    },
    {
        "stream": "STEM",
        "field_name": "Science and Research",
        "subject_name": "Mathematics",
        "requirement_type": "Required",
        "descriptions": "Scientific calculations, statistics, and analysis"
    },
    {
        "stream": "STEM",
        "field_name": "Science and Research",
        "subject_name": "Computer Applications Technology",
        "requirement_type": "Recommended",
        "descriptions": "Equips users with essential digital literacy, data management, and analytical skills needed to handle research"
    },
    {
        "stream": "STEM",
        "field_name": "Construction and Architecture",
        "subject_name": "Physical Sciences",
        "requirement_type": "Required",
        "descriptions": "Material science and physics principles"
    },
    {
        "stream": "STEM",
        "field_name": "Construction and Architecture",
        "subject_name": "Engineering Graphics & Design",
        "requirement_type": "Required",
        "descriptions": "Architectural design and drafting"
    },
    {
        "stream": "STEM",
        "field_name": "Construction and Architecture",
        "subject_name": "Technical Drawing",
        "requirement_type": "Required",
        "descriptions": "Architectural design and drafting"
    },
    {
        "stream": "STEM",
        "field_name": "Construction and Architecture",
        "subject_name": "Geography",
        "requirement_type": "Required",
        "descriptions": "Site analysis and environmental factors"
    },
    {
        "stream": "STEM",
        "field_name": "Construction and Architecture",
        "subject_name": "Computer Applications Technology",
        "requirement_type": "Required",
        "descriptions": "CAD software and design tools"
    },
    {
        "stream": "STEM",
        "field_name": "Construction and Architecture",
        "subject_name": "Mathematics",
        "requirement_type": "Required",
        "descriptions": "Structural calculations and measurements"
    },
    {
        "stream": "Commerce",
        "field_name": "Business and Finance",
        "subject_name": "Business Studies",
        "requirement_type": "Required",
        "descriptions": "Business fundamentals and management"
    },
    {
        "stream": "Commerce",
        "field_name": "Business and Finance",
        "subject_name": "Accounting",
        "requirement_type": "Required",
        "descriptions": "Core business accounting principles"
    },
    {
        "stream": "Commerce",
        "field_name": "Business and Finance",
        "subject_name": "Mathematics",
        "requirement_type": "Required",
        "descriptions": "Financial calculations, statistics, and analysis"
    },
    {
        "stream": "Commerce",
        "field_name": "Business and Finance",
        "subject_name": "Economics",
        "requirement_type": "Required",
        "descriptions": "Economic principles and market analysis"
    },
    {
        "stream": "Commerce",
        "field_name": "Hospitality and Tourism",
        "subject_name": "Tourism",
        "requirement_type": "Required",
        "descriptions": "Primary foundation of destination marketing, itinerary planning, and overall visitor experience"
    },
    {
        "stream": "Commerce",
        "field_name": "Hospitality and Tourism",
        "subject_name": "Hospitality Studies",
        "requirement_type": "Required",
        "descriptions": "Theoretical business management and practical delivery of guest experiences"
    },
    {
        "stream": "Commerce",
        "field_name": "Hospitality and Tourism",
        "subject_name": "Business Studies",
        "requirement_type": "Required",
        "descriptions": "Financial management and profitability"
    },
    {
        "stream": "Commerce",
        "field_name": "Hospitality and Tourism",
        "subject_name": "Consumer Studies",
        "requirement_type": "Required",
        "descriptions": "Understanding consumer behavior, enabling professionals to predict guest needs"
    },
    {
        "stream": "Commerce",
        "field_name": "Hospitality and Tourism",
        "subject_name": "Mathematical Literacy",
        "requirement_type": "Required",
        "descriptions": "Currency exchange, interpreting travel itineraries, and distance/time calculations"
    },
    {
        "stream": "Commerce",
        "field_name": "Hospitality and Tourism",
        "subject_name": "Geography",
        "requirement_type": "Recommended",
        "descriptions": "Destination management"
    },
    {
        "stream": "Commerce",
        "field_name": "Hospitality and Tourism",
        "subject_name": "History",
        "requirement_type": "Recommended",
        "descriptions": "Essential context needed to manage, market, and preserve the world's diverse travel destinations"
    },
    {
        "stream": "Humanities",
        "field_name": "Law and Legal Services",
        "subject_name": "History",
        "requirement_type": "Required",
        "descriptions": "Understanding legal systems and historical context"
    },
    {
        "stream": "Humanities",
        "field_name": "Law and Legal Services",
        "subject_name": "Business Studies",
        "requirement_type": "Required",
        "descriptions": "Commercial law and business principles"
    },
    {
        "stream": "Humanities",
        "field_name": "Law and Legal Services",
        "subject_name": "Economics",
        "requirement_type": "Required",
        "descriptions": "Economic context for legal cases"
    },
    {
        "stream": "Humanities",
        "field_name": "Law and Legal Services",
        "subject_name": "Mathematics",
        "requirement_type": "Required",
        "descriptions": "Logical reasoning and analytical skills"
    },
    {
        "stream": "Humanities",
        "field_name": "Art and Design",
        "subject_name": "Visual Arts",
        "requirement_type": "Required",
        "descriptions": "Creative expression, techniques, and aesthetics"
    },
    {
        "stream": "Humanities",
        "field_name": "Art and Design",
        "subject_name": "Music",
        "requirement_type": "Required",
        "descriptions": "A fundamental sensory layer that bridges auditory and visual storytelling"
    },
    {
        "stream": "Humanities",
        "field_name": "Art and Design",
        "subject_name": "Dramatic Arts",
        "requirement_type": "Required",
        "descriptions": "Equips you with the ability to read human experience and represent it through creative forms"
    },
    {
        "stream": "Humanities",
        "field_name": "Art and Design",
        "subject_name": "Design",
        "requirement_type": "Required",
        "descriptions": "Design principles, composition, and theory"
    },
    {
        "stream": "Humanities",
        "field_name": "Art and Design",
        "subject_name": "Dance Studies",
        "requirement_type": "Required",
        "descriptions": "Creative direction and choreography"
    },
    {
        "stream": "Humanities",
        "field_name": "Art and Design",
        "subject_name": "Mathematical Literacy",
        "requirement_type": "Required",
        "descriptions": "A practical bridge between creative vision and technical execution"
    },
    {
        "stream": "Humanities",
        "field_name": "Government and Public Services",
        "subject_name": "History",
        "requirement_type": "Required",
        "descriptions": "Understanding governance systems and historical context"
    },
    {
        "stream": "Humanities",
        "field_name": "Government and Public Services",
        "subject_name": "Business Studies",
        "requirement_type": "Required",
        "descriptions": "Public administration and management"
    },
    {
        "stream": "Humanities",
        "field_name": "Government and Public Services",
        "subject_name": "Economics",
        "requirement_type": "Required",
        "descriptions": "Understanding economic systems and public finance"
    },
    {
        "stream": "Humanities",
        "field_name": "Government and Public Services",
        "subject_name": "Accounting",
        "requirement_type": "Required",
        "descriptions": "Essential for financial documents and public budgeting"
    },
    {
        "stream": "Humanities",
        "field_name": "Government and Public Services",
        "subject_name": "Mathematics",
        "requirement_type": "Required",
        "descriptions": "Data analysis for policy development"
    },
    {
        "stream": "Humanities",
        "field_name": "Media and Communication",
        "subject_name": "Business Studies",
        "requirement_type": "Required",
        "descriptions": "Media business, marketing, and management"
    },
    {
        "stream": "Humanities",
        "field_name": "Media and Communication",
        "subject_name": "Economics",
        "requirement_type": "Required",
        "descriptions": "Essential for understanding media markets and consumer behavior"
    },
    {
        "stream": "Humanities",
        "field_name": "Media and Communication",
        "subject_name": "Psychology",
        "requirement_type": "Required",
        "descriptions": "Essential for understanding human behavior and audience engagement"
    },
    {
        "stream": "Humanities",
        "field_name": "Media and Communication",
        "subject_name": "Sociology",
        "requirement_type": "Required",
        "descriptions": "Essential for understanding human societies and cultural trends"
    },
    {
        "stream": "Humanities",
        "field_name": "Media and Communication",
        "subject_name": "Anthropology",
        "requirement_type": "Required",
        "descriptions": "Cultural context and global perspectives"
    },
    {
        "stream": "Humanities",
        "field_name": "Media and Communication",
        "subject_name": "History",
        "requirement_type": "Required",
        "descriptions": "Historical context for media evolution and storytelling"
    },
    {
        "stream": "Humanities",
        "field_name": "Media and Communication",
        "subject_name": "Computer Applications Technology",
        "requirement_type": "Required",
        "descriptions": "Digital media production and editing"
    },
    {
        "stream": "Humanities",
        "field_name": "Sports and Fitness",
        "subject_name": "Physical Education",
        "requirement_type": "Required",
        "descriptions": "Sports science, coaching, and training"
    },
    {
        "stream": "Humanities",
        "field_name": "Sports and Fitness",
        "subject_name": "Life Sciences",
        "requirement_type": "Required",
        "descriptions": "Human anatomy, physiology, kinesiology"
    },
    {
        "stream": "Humanities",
        "field_name": "Sports and Fitness",
        "subject_name": "Physical Sciences",
        "requirement_type": "Required",
        "descriptions": "Understanding human movement and optimizing athletic performance"
    },
    {
        "stream": "Humanities",
        "field_name": "Sports and Fitness",
        "subject_name": "Mathematics",
        "requirement_type": "Required",
        "descriptions": "Advanced math and algorithms to forecast future performance"
    }
]

# %%
def Interest_questionnaire():
    "The RIASEC interest questionnaire" 

    answers=[]

    print("=" * 60 )
    print("RIASEC interest questionnaire")
    print("=" * 60)
    print("Please type your answer to each question")


    print("\n1. Do you prefer working with your hands,tools,or machines, or do you prefer working with ideas and data?")
    ans=input(" ")
    answers.append(ans)

    print("\n2. When you have free time, do you prefer  building or fixing things,reading and research, or creatig art or muisic?")
    ans=input(" ")
    answers.append(ans)

    print("\n3.  Are you more drawn to solving logical problems(math,puzzels) or creative problems( designing, brainstorming)?")
    ans=input(" ")
    answers.append(ans)

    print("\n4. Do you enjoy leading groups, organizing events,or persuading others?")
    ans=input(" ")
    answers.append(ans)

    print("\n5. Do you prefer helping people directly (teaching, nursing,counseling) or working with data/things?")
    ans=input(" ")
    answers.append(ans)

    print("\n6. Do you like having clear rules and routines,or do you prefer flexibility and variety?": )
    ans=input(" ")
    answers.append(ans)

    print("\n7.Is it important to you that  others see you as an expert or leader in your field?": )
    ans=input(" ")
    answers.append(ans)
    
    print("\n8. Would you prefer a career where you are well-known and respected, or one where you work behind the scenes?": )
    ans=input(" ")
    answers.append(ans)

    print("\n9. Do you wnat your work to be recognised with awards, titles, or public acknowledgment?": )
    ans=input(" ")
    answers.append(ans)

    print("\n10. How important is it that your work directly helps other people or improves society?": )
    ans=input(" ")
    answers.append(ans)

    print("\n11. Would you sacrifice a higher salary to work for an organisation that makes a positive social impact?": )
    ans=input(" ")
    answers.append(ans)

    print("\n12. Do you feel  motivated by the work that addresses problems like poverty, disease, or environmental issues?": )
    ans=input(" ")
    answers.append(ans)

    print("\n13. Do  you prefer working alone,in small teams, or with large groups of people?": )
    ans=input(" ")
    answers.append(ans)

    print("\n14. Are you comfortable with frequent meetings, presentaions,  and group discussions?": )
    ans=input(" ")
    answers.append(ans)

    print("\n15. Do  you enjoy networking, building relatinships, and communicating with many different people?": )
    ans=input(" ")
    answers.append(ans)

    print("\n16. Would you describe yourself as someone who listens carefully to others' problems and concerns ?": )
    ans=input(" ")
    answers.append(ans)
    
    return answers

    return recommandation_database

    student_interest= Interest_questionnaire()
    print(student_interest)
